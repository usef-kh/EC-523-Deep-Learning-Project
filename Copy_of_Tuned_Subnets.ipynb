# %% [markdown]
# <a href="https://colab.research.google.com/github/usef-kh/EC523-Deep-Learning-Project/blob/master/Copy_of_Tuned_Subnets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Setup

# %%
# %%capture
# !git clone "https://github.com/usef-kh/EC523-Deep-Learning-Project.git"
# !pip install unrar
# !unrar e "EC523-Deep-Learning-Project/datasets/fer2013.rar"

# %% [markdown]
# ##Imports

# %%
import pandas as pd
import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
from torch import optim
from torch.utils.data import Dataset, DataLoader
from PIL import Image

import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ##Load Dataset

# %%
fer2013 = pd.read_csv('fer2013.csv') 
emotions = {0: 'Angry', 1: 'Disgust', 2: 'Fear', 3: 'Happy', 4: 'Sad', 5: 'Surprise', 6: 'Neutral'}
fer2013.head()

def prepare_data(data):
    """ Prepare data for modeling 
        input: data frame with labels und pixel data
        output: image and label array """
    
    image_array = np.zeros(shape=(len(data), 48, 48))
    image_label = np.array(list(map(int, data['emotion'])))
    
    for i, row in enumerate(data.index):
        image = np.fromstring(data.loc[row, 'pixels'], dtype=int, sep=' ')
        image = np.reshape(image, (48, 48))
        image_array[i] = image
        
    return image_array, image_label

xtrain, ytrain = prepare_data(fer2013[fer2013['Usage'] == 'Training'])
xval , yval = prepare_data(fer2013[fer2013['Usage'] == 'PrivateTest'])
xtest, ytest = prepare_data(fer2013[fer2013['Usage'] == 'PublicTest'])

# %%
class Fer2013(Dataset):
    def __init__(self, images, labels, transform=None):
        self.images = images
        self.labels = labels
        self.transform = transform        
        
    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()

        img = Image.fromarray(self.images[idx])
        
        if self.transform:
            img = self.transform(img)

        label = torch.tensor(self.labels[idx]).type(torch.long)
        sample = (img, label)
        
        return sample

mu, st = 0, 255
train_transform = transforms.Compose([
                    transforms.RandomResizedCrop(48, scale=(0.8, 1.2)),
                    transforms.RandomApply([transforms.RandomAffine(0, translate=(0.2, 0.2))], p=0.5),
                    transforms.RandomHorizontalFlip(),
                    transforms.RandomApply([transforms.RandomRotation(10)], p=0.5),
                    transforms.ToTensor(),
                    transforms.Normalize(mean=mu, std = st)
                    ])

test_transform = transforms.Compose([
                    transforms.ToTensor(),
                    transforms.Normalize(mean=mu, std = st)
                    ])

train = Fer2013(xtrain, ytrain, train_transform)
val = Fer2013(xval, yval, test_transform)
test = Fer2013(xtest, ytest, test_transform)

# %%
trainloader = torch.utils.data.DataLoader(train, batch_size=128, shuffle=True, num_workers=2)
valloader = torch.utils.data.DataLoader(val, batch_size=128, shuffle=True, num_workers=2)
testloader = torch.utils.data.DataLoader(test, batch_size=128, shuffle=True, num_workers=2)

# %%
def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)), cmap='gray')

# get some random training images
dataiter = iter(trainloader)
images, labels = dataiter.next()

print("Batch Images Shape:", images.shape)
print("Batch Labels Shape:", labels.shape)
print()

# show 5 images
imshow(torchvision.utils.make_grid(images[:5]))
plt.axis('off')
# print labels
print(' '.join('%7s' % emotions[labels[j].item()] for j in range(5)))
# Out:
# Batch Images Shape: torch.Size([128, 1, 48, 48])
# Batch Labels Shape: torch.Size([128])
#
# Neutral    Fear     Sad   Happy   Happy

# %% [markdown]
# ##Model

# %%
class History:
    def __init__(self):
        self.loss_train = []
        self.loss_val = []

        self.acc_train = []
        self.acc_val = []

# %% [markdown]
# ### Subnets

# %%
class Subnet1(nn.Module):
    def __init__(self):
        super(Subnet1, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=64, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(64, 128, 3, padding=1)
        self.conv3 = nn.Conv2d(128, 256, 3, padding=1)

        self.pool = nn.MaxPool2d(kernel_size=2,stride=2)
        
        self.bn1 = nn.BatchNorm2d(64)
        self.bn2 = nn.BatchNorm2d(128)
        self.bn3 = nn.BatchNorm2d(256)

        self.lin1 = nn.Linear(256 * 6 * 6, 4096) 
        self.lin2 = nn.Linear(4096, 4096)
        self.lin3 = nn.Linear(4096, 7)

        self.history = History()

        self.drop = nn.Dropout(p=0.2)

    def forward(self, x):
        x = F.relu(self.bn1(self.conv1(x)))
        x = self.pool(x)

        x = F.relu(self.bn2(self.conv2(x)))
        x = self.pool(x)

        x = F.relu(self.bn3(self.conv3(x)))
        x = self.pool(x)

        x = x.view(-1, 256*6*6) 
        
        x = F.relu(self.drop(self.lin1(x)))
        x = F.relu(self.drop(self.lin2(x)))
        
        x = self.lin3(x)

        return x

# %%
class Subnet2(nn.Module):
    def __init__(self):
        super(Subnet2, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=64, kernel_size=3, padding=1) # according to paper!
        self.conv2 = nn.Conv2d(64,128,3,padding=1)
        self.conv3 = nn.Conv2d(128, 256, 3, padding=1)
        self.conv3_2 = nn.Conv2d(256,256, 3, padding=1)

        self.pool = nn.MaxPool2d(kernel_size=2,stride=2)

        self.bn1 = nn.BatchNorm2d(64)
        self.bn2 = nn.BatchNorm2d(128)
        self.bn3 = nn.BatchNorm2d(256)
        self.bn3_2 = nn.BatchNorm2d(256)
        
        self.lin1 = nn.Linear(256 * 6 * 6, 4096)
        self.lin2 = nn.Linear(4096, 4096)
        self.lin3 = nn.Linear(4096, 7)

        self.history = History()

        self.drop = nn.Dropout(p=0.2)
        
    def forward(self, x):
        x = F.relu(self.bn1(self.conv1(x)))
        x = self.pool(x)

        x = F.relu(self.bn2(self.conv2(x)))
        x = self.pool(x)

        x = F.relu(self.bn3(self.conv3(x)))
        x = F.relu(self.bn3_2(self.conv3_2(x)))
        x = self.pool(x)

        x = x.view(x.size(0), 256 * 6 * 6)

        x = F.relu(self.drop(self.lin1(x)))
        x = F.relu(self.drop(self.lin2(x)))
        
        x = self.lin3(x)

        return x

# %%
class Subnet3(nn.Module):
    def __init__(self):
        super(Subnet3, self).__init__()

        self.conv1 = nn.Conv2d(in_channels=1, out_channels=64, kernel_size=3, padding=1) # according to paper!
        self.conv2 = nn.Conv2d(64,128,3,padding=1)
        self.conv2_2 = nn.Conv2d(128,128,3,padding=1)
        self.conv3 = nn.Conv2d(128, 256, 3, padding=1)
        self.conv3_2 = nn.Conv2d(256,256, 3, padding=1)

        self.pool = nn.MaxPool2d(kernel_size=2,stride=2)

        self.bn1 = nn.BatchNorm2d(num_features= 64)
        self.bn2 = nn.BatchNorm2d(num_features= 128)
        self.bn2_2 = nn.BatchNorm2d(num_features= 128)
        self.bn3 = nn.BatchNorm2d(num_features= 256)
        self.bn3_2 = nn.BatchNorm2d(num_features= 256)

        self.lin1 = nn.Linear(256 * 6 * 6, 4096)
        self.lin2 = nn.Linear(4096, 4096)
        self.lin3 = nn.Linear(4096, 7)

        self.history = History()
        
    def forward(self, x):

        x = F.relu(self.bn1(self.conv1(x)))
        x = self.pool(x)

        x = F.relu(self.bn2(self.conv2(x)))
        x = F.relu(self.bn2_2(self.conv2_2(x)))
        x = self.pool(x)

        x = F.relu(self.bn3(self.conv3(x)))
        x = F.relu(self.bn3_2(self.conv3_2(x)))
        x = self.pool(x)

        x = x.view(-1, 256*6*6)
      
        x = F.relu(self.lin1(x))
        x = F.relu(self.lin2(x))
        
        x = self.lin3(x)

        return x

# %% [markdown]
# ### Ensemble

# %% [markdown]
# ##Training

# %%
from torch.optim.lr_scheduler import ReduceLROnPlateau

def train_model(net, trainloader, valloader, n_epochs=20):
    
    for epoch in range(n_epochs):
        
        net = net.train()
        loss_tr, correct_count, n = 0.0, 0.0, 0.0
        for i, data in enumerate(trainloader):
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)
            
            # zero the parameter gradients
            optimizer.zero_grad()
            
            # forward + backward + optimize
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            # calculate performance metrics
            loss_tr += loss.item()
            
            _, preds = torch.max(outputs.data, 1)
            correct_count += (preds == labels).sum().item()
            n += labels.size(0)
            
        # Save train and validation performance metrics 
        acc_tr = 100 * correct_count / n
        loss_tr = loss_tr / n

        acc_v, loss_v = test_model(net, valloader)

        net.history.loss_train.append(loss_tr)
        net.history.loss_val.append(loss_v)

        net.history.acc_train.append(acc_tr)
        net.history.acc_val.append(acc_v)
        scheduler.step(acc_v)
        # print(optimizer.param_groups[0]['lr'])
        print('Epoch %2d' % (epoch + 1), 'Train Accuracy: %2.2f %%' % (acc_tr), 'Val Accuracy: %2.2f %%' % (acc_v), sep='\t\t')

# %%
def test_model(net, dataloader):
    
    net = net.eval()

    loss, correct_count, n_sampels = 0.0, 0.0, 0.0
    for data in dataloader:

        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)

        outputs = net(inputs)

        loss += criterion(outputs, labels).item()

        _, preds = torch.max(outputs.data, 1)
        correct_count += (preds == labels).sum().item()
        n_sampels += labels.size(0)
    
    acc = 100 * correct_count / n_sampels
    loss = loss / n_sampels
    
    return acc, loss

# %%
sub1 = Subnet1()
sub1 = sub1.to(device)
learning_rate = 0.1
optimizer = torch.optim.SGD(sub1.parameters(), lr=learning_rate, momentum=0.9, nesterov=True, weight_decay=0.0001)
scheduler = ReduceLROnPlateau(optimizer, mode='max', factor=0.5, patience=10, verbose=True)
criterion = nn.CrossEntropyLoss()
train_model(sub1, trainloader, valloader, n_epochs=150)

sub2 = Subnet2()
sub2 = sub2.to(device)
learning_rate = 0.1
optimizer = torch.optim.SGD(sub2.parameters(), lr=learning_rate, momentum=0.9, nesterov=True, weight_decay=0.0001)
scheduler = ReduceLROnPlateau(optimizer, mode='max', factor=0.5, patience=10, verbose=True)
criterion = nn.CrossEntropyLoss()
train_model(sub2, trainloader, valloader, n_epochs=150)


path1 = 'sub1_drop'
path2 = 'sub2_drop'
torch.save(sub1.state_dict(), path1)
torch.save(sub2.state_dict(), path2)
# Out:
# Epoch  1		Train Accuracy: 14.80 %		Val Accuracy: 13.68 %
# Epoch  2		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch  3		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch  4		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch  5		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch  6		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch  7		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch  8		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch  9		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 10		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 11		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch    12: reducing learning rate of group 0 to 5.0000e-02.
# Epoch 12		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 13		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 14		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 15		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 16		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 17		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 18		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 19		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 20		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 21		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 22		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch    23: reducing learning rate of group 0 to 2.5000e-02.
# Epoch 23		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 24		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 25		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 26		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 27		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 28		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 29		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 30		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 31		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 32		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 33		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch    34: reducing learning rate of group 0 to 1.2500e-02.
# Epoch 34		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 35		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 36		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 37		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 38		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 39		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 40		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 41		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 42		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 43		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 44		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch    45: reducing learning rate of group 0 to 6.2500e-03.
# Epoch 45		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 46		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 47		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 48		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 49		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 50		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 51		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 52		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 53		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 54		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 55		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch    56: reducing learning rate of group 0 to 3.1250e-03.
# Epoch 56		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 57		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 58		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 59		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 60		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 61		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 62		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 63		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 64		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 65		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 66		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch    67: reducing learning rate of group 0 to 1.5625e-03.
# Epoch 67		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 68		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 69		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 70		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 71		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 72		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 73		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 74		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 75		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 76		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 77		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch    78: reducing learning rate of group 0 to 7.8125e-04.
# Epoch 78		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 79		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 80		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 81		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 82		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 83		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %
# Epoch 84		Train Accuracy: 13.92 %		Val Accuracy: 13.68 %

# %%
print("Subnet 1")
plot_metrics(sub1)
# Out:
# Subnet 1
# Training Accuracy: 87.06 %
# Validation Accuracy: 69.57 %
#
# Test Accuracy: 68.01 %
# Average Test Loss: 0.0117

# %%
path1 = 'sub1_drop'
path2 = 'sub2_drop'
torch.save(sub1.state_dict(), path1)
torch.save(sub2.state_dict(), path2)

# %%
net1 = Subnet1()
net1.load_state_dict(torch.load('sub1_drop'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-750c63791d17> in <module>()
#       1 net1 = Subnet1()
# ----> 2 net1.load_state_dict(torch.load('sub1_drop'))
#
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     569         pickle_load_args['encoding'] = 'utf-8'
#     570
# --> 571     with _open_file_like(f, 'rb') as opened_file:
#     572         if _is_zipfile(opened_file):
#     573             # The zipfile reader is going to advance the current file position.
#
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py in _open_file_like(name_or_buffer, mode)
#     227 def _open_file_like(name_or_buffer, mode):
#     228     if _is_path(name_or_buffer):
# --> 229         return _open_file(name_or_buffer, mode)
#     230     else:
#     231         if 'w' in mode:
#
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py in __init__(self, name, mode)
#     208 class _open_file(_opener):
#     209     def __init__(self, name, mode):
# --> 210         super(_open_file, self).__init__(open(name, mode))
#     211
#     212     def __exit__(self, *args):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sub1_drop'

# %%
path = 'sub1'
torch.save(sub1.state_dict(), path)

# %%
sub2 = Subnet2()
sub2 = sub2.to(device)

learning_rate = 0.1
optimizer = torch.optim.SGD(sub2.parameters(), lr=learning_rate, momentum=0.9, nesterov=True, weight_decay=0.0001)
scheduler = ReduceLROnPlateau(optimizer, mode='max', factor=0.5, patience=10, verbose=True)
criterion = nn.CrossEntropyLoss()
train_model(sub2, trainloader, valloader, n_epochs=150)

path = 'sub2'
torch.save(sub2.state_dict(), path)
# Out:
# Epoch  1		Train Accuracy: 24.12 %		Val Accuracy: 24.69 %
# Epoch  2		Train Accuracy: 25.07 %		Val Accuracy: 24.63 %
# Epoch  3		Train Accuracy: 24.98 %		Val Accuracy: 24.91 %
# Epoch  4		Train Accuracy: 25.56 %		Val Accuracy: 25.91 %
# Epoch  5		Train Accuracy: 29.12 %		Val Accuracy: 35.11 %
# Epoch  6		Train Accuracy: 34.52 %		Val Accuracy: 36.19 %
# Epoch  7		Train Accuracy: 39.50 %		Val Accuracy: 37.17 %
# Epoch  8		Train Accuracy: 43.59 %		Val Accuracy: 38.90 %
# Epoch  9		Train Accuracy: 46.58 %		Val Accuracy: 48.87 %
# Epoch 10		Train Accuracy: 48.98 %		Val Accuracy: 46.56 %
# Epoch 11		Train Accuracy: 51.15 %		Val Accuracy: 48.48 %
# Epoch 12		Train Accuracy: 52.74 %		Val Accuracy: 56.90 %
# Epoch 13		Train Accuracy: 53.88 %		Val Accuracy: 54.22 %
# Epoch 14		Train Accuracy: 54.99 %		Val Accuracy: 53.36 %
# Epoch 15		Train Accuracy: 55.61 %		Val Accuracy: 54.39 %
# Epoch 16		Train Accuracy: 56.52 %		Val Accuracy: 53.47 %
# Epoch 17		Train Accuracy: 57.13 %		Val Accuracy: 58.87 %
# Epoch 139		Train Accuracy: 89.01 %		Val Accuracy: 70.13 %
# Epoch 140		Train Accuracy: 89.28 %		Val Accuracy: 69.80 %
# Epoch 141		Train Accuracy: 89.40 %		Val Accuracy: 70.16 %
# Epoch 142		Train Accuracy: 89.20 %		Val Accuracy: 70.08 %
# Epoch 143		Train Accuracy: 89.32 %		Val Accuracy: 70.02 %
# Epoch 144		Train Accuracy: 89.66 %		Val Accuracy: 69.82 %
# Epoch 145		Train Accuracy: 89.18 %		Val Accuracy: 69.71 %
# Epoch 146		Train Accuracy: 89.68 %		Val Accuracy: 69.82 %
# Epoch 147		Train Accuracy: 89.60 %		Val Accuracy: 69.66 %
# Epoch 148		Train Accuracy: 89.34 %		Val Accuracy: 70.13 %
# Epoch 149		Train Accuracy: 89.48 %		Val Accuracy: 70.08 %
# Epoch 150		Train Accuracy: 89.45 %		Val Accuracy: 69.85 %

# %%
sub3 = Subnet3()
sub3 = sub3.to(device)

learning_rate = 0.1
optimizer = torch.optim.SGD(sub3.parameters(), lr=learning_rate, momentum=0.9, nesterov=True, weight_decay=0.0001)
scheduler = ReduceLROnPlateau(optimizer, mode='max', factor=0.5, patience=10, verbose=True)
criterion = nn.CrossEntropyLoss()
train_model(sub3, trainloader, valloader, n_epochs=150)

path = 'sub3'
torch.save(sub3.state_dict(), path)

# %% [markdown]
# ##Evaluation

# %%
def plot_metrics(net):
    plt.figure()
    plt.plot(net.history.acc_train, 'g', label='Training Acc')
    plt.plot(net.history.acc_val, 'b', label='Validation Acc')
    plt.title('Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Acc')
    plt.legend()
    plt.grid()
    plt.show()

    plt.figure()
    plt.plot(net.history.loss_train, 'g', label='Training Loss')
    plt.plot(net.history.loss_val, 'b', label='Validation Loss')
    plt.title('Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid()
    plt.show()

    print('Training Accuracy: %2.2f %%' % (max(net.history.acc_train)))
    print('Validation Accuracy: %2.2f %%' % (max(net.history.acc_val)))
    print()

    acc, loss = test_model(net, testloader)    
    print('Test Accuracy: %2.2f %%' % (acc))
    print('Average Test Loss: %2.4f' % (loss))

# %% [markdown]
# ### Subnets

# %%
print("Subnet 1")
plot_metrics(sub1)
# Out:
# Subnet 1
# Training Accuracy: 85.07 %
# Validation Accuracy: 66.82 %
#
# Test Accuracy: 66.06 %
# Average Test Loss: 0.0123

# %%
print("Subnet 1")
plot_metrics(sub1)
# Out:
# Subnet 1
# Training Accuracy: 97.75 %
# Validation Accuracy: 67.85 %
#
# Test Accuracy: 66.82 %
# Average Test Loss: 0.0195

# %%
print("Subnet 2")
plot_metrics(sub2)
# Out:
# Subnet 2
# Training Accuracy: 89.68 %
# Validation Accuracy: 70.16 %
#
# Test Accuracy: 68.93 %
# Average Test Loss: 0.0119

# %%
print("Subnet 2")
plot_metrics(sub2)
# Out:
# Subnet 2
# Training Accuracy: 92.76 %
# Validation Accuracy: 70.74 %
#
# Test Accuracy: 68.38 %
# Average Test Loss: 0.0145

# %%
print("Subnet 3")
plot_metrics(sub3)
# Out:
# Subnet 3
# Training Accuracy: 83.74 %
# Validation Accuracy: 70.10 %
#
# Test Accuracy: 66.93 %
# Average Test Loss: 0.0098

# %%
print("Subnet 3")
plot_metrics(sub3)
# Out:
# Subnet 3
# Training Accuracy: 98.53 %
# Validation Accuracy: 69.16 %
#
# Test Accuracy: 66.90 %
# Average Test Loss: 0.0199

# %% [markdown]
# ##Save Model

# %%
path = 'sub2'
torch.save(sub2.state_dict(), path)

# %%
# from google.colab import files
# files.download(path)
